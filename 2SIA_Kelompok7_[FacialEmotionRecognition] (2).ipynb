# %% [markdown]
# <a href="https://colab.research.google.com/github/komalck/project/blob/master/Facial_emotion_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from zipfile import ZipFile
file_name = '/content/drive/MyDrive/CONTENT/archive.zip'

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print("Done")
# Out:
# Done

# %%
import numpy as np
import cv2
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D
from tensorflow.keras.optimizers import Adam
from keras.layers import MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = 'train'
val_dir = 'test'
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        val_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
emotion_model = Sequential()
emotion_model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
emotion_model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))
emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))
emotion_model.add(Flatten())
emotion_model.add(Dense(1024, activation='relu'))
emotion_model.add(Dropout(0.5))
emotion_model.add(Dense(7, activation='softmax'))

# %%
emotion_model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.0001, decay=1e-6),metrics=['accuracy'])
emotion_model_info = emotion_model.fit_generator(
        train_generator,
        steps_per_epoch=28709 // 64,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=7178 // 64)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# 448/448 [==============================] - 24s 28ms/step - loss: 1.7913 - accuracy: 0.2668 - val_loss: 1.6812 - val_accuracy: 0.3485
# Epoch 2/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.6132 - accuracy: 0.3735 - val_loss: 1.5369 - val_accuracy: 0.4135
# Epoch 3/50
# 448/448 [==============================] - 13s 28ms/step - loss: 1.5256 - accuracy: 0.4154 - val_loss: 1.4682 - val_accuracy: 0.4425
# Epoch 4/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.4565 - accuracy: 0.4438 - val_loss: 1.4011 - val_accuracy: 0.4703
# Epoch 5/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.3975 - accuracy: 0.4700 - val_loss: 1.3498 - val_accuracy: 0.4870
# Epoch 6/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.3484 - accuracy: 0.4872 - val_loss: 1.3204 - val_accuracy: 0.4934
# Epoch 7/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.3048 - accuracy: 0.5087 - val_loss: 1.2796 - val_accuracy: 0.5137
# Epoch 8/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.2666 - accuracy: 0.5202 - val_loss: 1.2580 - val_accuracy: 0.5264
# Epoch 9/50
# 448/448 [==============================] - 12s 27ms/step - loss: 1.2296 - accuracy: 0.5335 - val_loss: 1.2216 - val_accuracy: 0.5350
# Epoch 10/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.2007 - accuracy: 0.5486 - val_loss: 1.2022 - val_accuracy: 0.5435
# Epoch 11/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.1710 - accuracy: 0.5599 - val_loss: 1.1813 - val_accuracy: 0.5501
# Epoch 12/50
# 448/448 [==============================] - 12s 27ms/step - loss: 1.1485 - accuracy: 0.5686 - val_loss: 1.1735 - val_accuracy: 0.5539
# Epoch 13/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.1185 - accuracy: 0.5796 - val_loss: 1.1509 - val_accuracy: 0.5665
# Epoch 14/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.0947 - accuracy: 0.5887 - val_loss: 1.1392 - val_accuracy: 0.5667
# Epoch 15/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.0697 - accuracy: 0.6032 - val_loss: 1.1224 - val_accuracy: 0.5727
# Epoch 16/50
# 448/448 [==============================] - 11s 25ms/step - loss: 1.0447 - accuracy: 0.6135 - val_loss: 1.1125 - val_accuracy: 0.5798
# Epoch 17/50
# 448/448 [==============================] - 11s 24ms/step - loss: 1.0232 - accuracy: 0.6180 - val_loss: 1.1072 - val_accuracy: 0.5820
# Epoch 18/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.9926 - accuracy: 0.6298 - val_loss: 1.0978 - val_accuracy: 0.5875
# Epoch 19/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.9704 - accuracy: 0.6401 - val_loss: 1.0852 - val_accuracy: 0.5935
# Epoch 20/50
# 448/448 [==============================] - 12s 27ms/step - loss: 0.9498 - accuracy: 0.6514 - val_loss: 1.0804 - val_accuracy: 0.5936
# Epoch 21/50
# 448/448 [==============================] - 12s 26ms/step - loss: 0.9232 - accuracy: 0.6621 - val_loss: 1.0816 - val_accuracy: 0.5967
# Epoch 22/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.9019 - accuracy: 0.6680 - val_loss: 1.0734 - val_accuracy: 0.5991
# Epoch 23/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.8768 - accuracy: 0.6758 - val_loss: 1.0765 - val_accuracy: 0.6002
# Epoch 24/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.8520 - accuracy: 0.6858 - val_loss: 1.0687 - val_accuracy: 0.5999
# Epoch 25/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.8332 - accuracy: 0.6927 - val_loss: 1.0562 - val_accuracy: 0.6038
# Epoch 26/50
# 448/448 [==============================] - 12s 28ms/step - loss: 0.8109 - accuracy: 0.7019 - val_loss: 1.0652 - val_accuracy: 0.6104
# Epoch 27/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.7804 - accuracy: 0.7178 - val_loss: 1.0651 - val_accuracy: 0.6077
# Epoch 28/50
# 448/448 [==============================] - 12s 27ms/step - loss: 0.7633 - accuracy: 0.7210 - val_loss: 1.0551 - val_accuracy: 0.6116
# Epoch 29/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.7348 - accuracy: 0.7294 - val_loss: 1.0678 - val_accuracy: 0.6143
# Epoch 30/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.7144 - accuracy: 0.7386 - val_loss: 1.0605 - val_accuracy: 0.6148
# Epoch 31/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.6928 - accuracy: 0.7503 - val_loss: 1.0691 - val_accuracy: 0.6110
# Epoch 32/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.6678 - accuracy: 0.7569 - val_loss: 1.0821 - val_accuracy: 0.6130
# Epoch 33/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.6544 - accuracy: 0.7657 - val_loss: 1.0630 - val_accuracy: 0.6191
# Epoch 34/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.6243 - accuracy: 0.7730 - val_loss: 1.0832 - val_accuracy: 0.6150
# Epoch 35/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.6110 - accuracy: 0.7762 - val_loss: 1.0769 - val_accuracy: 0.6205
# Epoch 36/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.5904 - accuracy: 0.7844 - val_loss: 1.0756 - val_accuracy: 0.6246
# Epoch 37/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.5706 - accuracy: 0.7944 - val_loss: 1.0975 - val_accuracy: 0.6205
# Epoch 38/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.5484 - accuracy: 0.8006 - val_loss: 1.0974 - val_accuracy: 0.6211
# Epoch 39/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.5350 - accuracy: 0.8060 - val_loss: 1.0900 - val_accuracy: 0.6173
# Epoch 40/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.5189 - accuracy: 0.8129 - val_loss: 1.1070 - val_accuracy: 0.6210
# Epoch 41/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.5030 - accuracy: 0.8170 - val_loss: 1.1170 - val_accuracy: 0.6205
# Epoch 42/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.4845 - accuracy: 0.8243 - val_loss: 1.1199 - val_accuracy: 0.6211
# Epoch 43/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.4723 - accuracy: 0.8296 - val_loss: 1.1434 - val_accuracy: 0.6204
# Epoch 44/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.4539 - accuracy: 0.8377 - val_loss: 1.1370 - val_accuracy: 0.6243
# Epoch 45/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.4377 - accuracy: 0.8406 - val_loss: 1.1338 - val_accuracy: 0.6222
# Epoch 46/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.4181 - accuracy: 0.8499 - val_loss: 1.1697 - val_accuracy: 0.6175
# Epoch 47/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.4051 - accuracy: 0.8549 - val_loss: 1.1871 - val_accuracy: 0.6239
# Epoch 48/50
# 448/448 [==============================] - 11s 24ms/step - loss: 0.3949 - accuracy: 0.8583 - val_loss: 1.1749 - val_accuracy: 0.6221
# Epoch 49/50
# 448/448 [==============================] - 11s 25ms/step - loss: 0.3805 - accuracy: 0.8636 - val_loss: 1.1826 - val_accuracy: 0.6254
# Epoch 50/50
# 448/448 [==============================] - 15s 33ms/step - loss: 0.3814 - accuracy: 0.8634 - val_loss: 1.1808 - val_accuracy: 0.6250

# %%
#Saving the model
emotion_model.save('model.h5')

# %%
from keras.models import load_model
emotion_model = load_model('model.h5')

# %%
def emotion_analysis(emotions):
    objects = ('angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral')
    y_pos = np.arange(len(objects))
    
    plt.bar(y_pos, emotions, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')
    
    plt.show()

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
take_photo()
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-16-811c52a3a963> in <module>()
# ----> 1 take_photo()
#
# <ipython-input-15-9a3bc4379e3c> in take_photo(filename, quality)
#      36     ''')
#      37   display(js)
# ---> 38   data = eval_js('takePhoto({})'.format(quality))
#      39   binary = b64decode(data.split(',')[1])
#      40   with open(filename, 'wb') as f:
#
# /usr/local/lib/python3.7/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result, timeout_sec)
#      38   if ignore_result:
#      39     return
# ---> 40   return _message.read_reply_from_input(request_id, timeout_sec)
#      41
#      42
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: NotFoundError: Requested device not found

# %%
import cv2
            
def facecrop(image):  
    facedata = '/content/haarcascade_frontalface_alt.xml'
    cascade = cv2.CascadeClassifier(facedata)

    img = cv2.imread(image)

    try:
    
        minisize = (img.shape[1],img.shape[0])
        miniframe = cv2.resize(img, minisize)

        faces = cascade.detectMultiScale(miniframe)

        for f in faces:
            x, y, w, h = [ v for v in f ]
            cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

            sub_face = img[y:y+h, x:x+w]

            
            cv2.imwrite('photo.jpg', sub_face)
            print ("Writing: " + image)

    except Exception as e:
        print (e)

if __name__ == '__main__':
    facecrop('/content/photo.jpg')

#Testing a file.

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt


file = '/content/photo.jpg'
true_image = image.load_img(file)
img = image.load_img(file, color_mode="grayscale", target_size=(48, 48))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom = emotion_model.predict(x)
emotion_analysis(custom[0])

x = np.array(x, 'float32')
x = x.reshape([48, 48]);


plt.imshow(true_image)
plt.show()
# Out:
# 'NoneType' object has no attribute 'shape'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-4ca67ad7be5e> in <module>()
#      40
#      41 file = '/content/photo.jpg'
# ---> 42 true_image = image.load_img(file)
#      43 img = image.load_img(file, color_mode="grayscale", target_size=(48, 48))
#      44
#
# /usr/local/lib/python3.7/dist-packages/keras/preprocessing/image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     312   """
#     313   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
# --> 314                         target_size=target_size, interpolation=interpolation)
#     315
#     316
#
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     111         raise ImportError('Could not import PIL.Image. '
#     112                           'The use of `load_img` requires PIL.')
# --> 113     with open(path, 'rb') as f:
#     114         img = pil_image.open(io.BytesIO(f.read()))
#     115         if color_mode == 'grayscale':
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/photo.jpg'

# %%
from google.colab import files

# %%
#Testing a file.

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt

uploaded = files.upload()
for fn in uploaded.keys():
  path = fn
  true_image = image.load_img(path)
  img = image.load_img(path, color_mode="grayscale", target_size=(48, 48))

  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  x /= 255

  custom = emotion_model.predict(x)
  emotion_analysis(custom[0])

  x = np.array(x, 'float32')
  x = x.reshape([48, 48]);


  plt.imshow(true_image)
  plt.show()
# Out:
#      <input type="file" id="files-fa644738-33d3-46dd-b4ae-19f79e450018" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa644738-33d3-46dd-b4ae-19f79e450018">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 32314.png to 32314.png
